# %% [markdown]
# # 파이썬 일주일 생존게임

# %%
inv=["없음"]
root=[1,2,3]
over=[1,2,3]
player=["temp",100,inv]

sleep_check=0
sleep_stack=0

root[0]=f"{player[0]}님은 이제 우꿀꿀루 종족의 일원이 되었습니다. 그 물약을 마시자마자 인간의 모습은 온데간데 사라지고 사랑스러운 촉수들이 돋아났네요.\n앞으로 새로운 동료들과 함께 얼마나 많은 지구인을 납치하게 될지 기대됩니다!\n--외계화 엔딩--"
root[1]=f"차가운 강철 바닥에는 옛 두목의 살점이 다진 햄버거 패티처럼 퍼져있습니다. 이미 죽은게 확실하지만 산낙지처럼 꿈틀대는 근육이 기분 나쁘군요... \n이제 과거 우꿀룰루 종족의 영웅은 우리 곁을 영영 떠났습니다. 새로운 두목 {player[0]}님을 찬양하라!\n--두목 엔딩--"
root[2]=f"{player[0]}님은 우꿀룰루 종족의 실험체가 되는 서류에 서명했습니다. 이제 지구에 있는 엄마아빠 친구들을 다시 만날 수는 없지만 들어보세요... \n목성뷰 원룸에 기초적인 의식주가 평생 무료제공됩니다. 이 경제에 말이죠! 다만 어느날 눈을 감았다 뜨면 모르는 팔이 하나 더 생겨있을지도 모릅니다...--실험체 엔딩--"

over[0]=f"{player[0]}님은 우꿀꿀루 종족의 제안을 거절했습니다. 그는 잠시 고민하는 듯 싶더니... 즉시 돌변해 당신에게 외계총을 발사합니다! 그것도 56방이나요!\n한 발만 맞아도 죽었을텐데 56방은 역시 너무했습니다. {player[0]}님은 구멍이 숭숭 난 채로 바닥에서 식어갑니다.\n마지막 의식이 바라보는 건 내 덩치와 맞먹는 상자를 들고 다가오는 우꿀꿀루족 청소부입니다. 치우는데 고생 좀 하겠네요. \n***게임 오버***"
over[1]=f"{player[0]}즉시 사방에서 광선이 날아와 당신을 회색 재로 만들어버렸습니다.\n그래도 고통은 없었으니 호상일까요... {player[0]}님의 여정은 여기서 끝이 납니다.\n***게임오버***"
over[2]=f"아아... 더이상 버틸 수가 없어...\n풀썩\n차가운 외계함선의 바닥에 당신은 힘없이 쓰러집니다. 더이상 앞으로 나아가긴 어려워 보이네요...\n쪼그라든 당신의 시체는 담당자가 수거해 다른 실험체들의 사료를 만드는데 사용했습니다.\n***게임오버***"

search=0
sleep=0
fight=0
hidden=0

game_end=1

print("당신은 외계 함선에 납치당했다! 그대에게 주어진 시간은 단 일주일...\n아이템과 정보를 모으고 살아남아 탈출해보자.")

player[0] = input("납치당한 그대의 이름은...? >>> ")
print(f"당신의 이름은 {player[0]}...")

while game_end==1:
    print(" --- 첫번째 날 (월) ---")
    print(" ! 당신은 낯선 외계함선에 갇혀있다.")
    print(f"[ 이름: {player[0]} 체력: {player[1]} 인벤: {player[2]} ]")
    day = input("[ 탐색 / 수면 / 전투 ]")
    if day == "탐색":
        search+=1
        print("[탐색] 당신은 쓸만한 것이 없나 근처를 살피기 시작했다.\n낙지처럼 생긴 탄환을 발견했다!\n[ 낙지탄 획득 ]\n하루가 지나간다.")
        inv[0]=("낙지탄")
        break
    elif day == "수면":
        sleep+=1
        print("[수면] 이건 전부 다 꿈일거야... 당신은 현실을 부정하며 눈을 감습니다.\n꿈이 아니었습니다.\n하루가 지나간다.")
        sleep_check+=1
        break
    elif day == "전투":
        fight+=1
        print("[전투] 빌어먹을 외계인놈들... 당신은 끓어오르는 분노를 참을 수가 없습니다!\n맨 주먹만으로 당신은 낯선 외계종족에게 달려듭니다.")
        print("어쩌면 주먹질은 이 종족 사이에서 통용되는 인사인 걸까요? 외계인은 반가운 듯 당신의 손을 붙잡고 말을 겁니다.")
        print("전혀 알아들을 수 없지만... 어째서인지 뇌를 통해 직접적으로 의미가 느껴지네요.")

        print("외계인: 안그래도 어디가셨나 했습니다. 실험체 계약을 마저 진행해볼까요?")
        answer=input("외계인의 제안을 받아들일까요? (네/아니오)")
        if answer=="네":
            print(root[2])
            game_end==0
            break
        elif answer=="아니오":
            print(over[0])
            game_end==0
            break
        else:
            print("외계인은 당신의 말을 이해할 수 없어 화가났습니다.\n차가운 우주 밖으로 당신은 내던져집니다...\n-- 방출엔딩 --")
            game_end==0
        break
    else:
        print("제대로 입력해주세요.")

    break


while game_end==1:
    print(" --- 두번째 날 (화) ---")
    print(" ! 외계인들의 대화를 엿듣다보니 그들은 '우꿀꿀루' 종족 이라는 것을 알게되었다.")
    print(f"[ 이름: {player[0]} 체력: {player[1]} 인벤: {player[2]}")
    day = input("[ 탐색 / 수면 / 전투 ]")
    if day == "탐색":
        search+=1
        sleep_check==0
        print("[탐색] 당신은 쓸만한 것이 없나 근처를 살피기 시작했다.\n오늘은 별로 특별한 물건을 찾지 못했다.\n하루가 지나간다.")
        break
    elif day == "수면":
        print("[수면] 이건 전부 다 꿈일거야... 당신은 현실을 부정하며 눈을 감습니다.\n꿈이 아니었습니다.\n하루가 지나간다.")
        if sleep_check==0:
            sleep_check+=1
        else:
            sleep_stack+=1
            if sleep_stack==3:
                print(over[2])
                game_end==0
                break
        break
    elif day == "전투":
        search+=1
        sleep_check==0
        print("[전투] 어디 혼내줄 외계인이 없나 둘러보던 와중, 당신은 어린 개체가 총을 들고 노는 것을 발견합니다.")
        if inv[0]=="낙지탄":
            print("저 총이라면 당신이 가지고 있는 낙지탄이 쏙 들어갈 것 같습니다! 아이를 혼쭐내고 총을 빼앗을까요?")
            answer=input("네/아니오")
            if answer=="네":
                print("당신은 아이에게 꿀밤을 먹이고 총을 빼앗습니다. 식은 죽 먹기네요. \n[ 외계총 획득 ]")
                inv.append("외계총")
                break
            else:
                print("어린아이는 꽃으로도 때리지 말라 했습니다. 당신은 아이를 그냥 지나칩니다.")
                break
        elif inv[0]=="없음":
            print("저렇게 어린아이가 가지고 놀고있는 총이라면 중요한 부품은 모두 빠져있는 총이겠군요. 쓸모가 없겠습니다.")
            print("아무것도 얻지 못했다.\n하루가 지나간다.")
            break
    
    else:
        print("제대로 입력해주세요.")

    break


while game_end==1:
    print(" --- 세번째 날 (수) ---")
    print(" ! 외계인들에게도 오락채널이 있다는 사실을 알아냈습니다. 이름은 외계도전이라네요...")
    print(f"[ 이름: {player[0]} 체력: {player[1]} 인벤: {player[2]} ]")
    day = input("[ 탐색 / 수면 / 전투 ]")
    if day == "탐색":
        search+=1
        sleep_check==0
        player[1]-=50
        hidden=1
        print("[탐색] 당신은 쓸만한 것이 없나 근처를 살피기 시작했다.\n외계함정이다!! 콰아아아앙 - \n[체력 -50]\n 다리 한 쪽을 잃고 하루가 지나간다.")
        break
    elif day == "수면":
        sleep+=1
        print("[수면] 이건 전부 다 꿈일거야... 당신은 현실을 부정하며 눈을 감습니다.\n꿈이 아니었습니다.\n하루가 지나간다.")
        if sleep_check==0:
            sleep_check+=1
        else:
            sleep_stack+=1
            if sleep_stack==3:
                print(over[2])
                game_end==0
                break
        break
    elif day == "전투":
        fight+=1
        sleep_check==0
        player[1]-=30
        print("[전투] 지구에서 당신은 싸움꾼이었을까요? 눈 앞의 외계인에게 당신은 바디슬램을 날립니다.")
        print("그러자 물컹물컹한 외계인 몸에 그대로 당신의 몸이 박혀버렸습니다... 몸의 모든 구멍에서 초록 즙이 나오네요.")
        print("[체력 -30]\n하루가 지나간다.")
    
    else:
        print("제대로 입력해주세요.")

    break


while game_end==1:
    print(" --- 네번째 날 (목) ---")
    if player[1]<=0:
        print(over[2])
        game_end==0
        break
    print(" ! 역시 우주에 있어서 그런가 창밖 뷰는 끝내주네요.")
    print(f"[ 이름: {player[0]} 체력: {player[1]} 인벤: {player[2]} ]")
    day = input("[ 탐색 / 수면 / 전투 ]")
    if day == "탐색":
        search+=1
        sleep_check==0
        print("[탐색] 당신은 쓸만한 것이 없나 근처를 살피기 시작했다.\n열쇠를 찾았다! 어디로 가는 열쇠일까?\n[ 열쇠 획득 ]\n하루가 지나간다.")
        inv.append("열쇠")
        break
    elif day == "수면":
        sleep+=1
        print("[수면] 이건 전부 다 꿈일거야... 당신은 현실을 부정하며 눈을 감습니다.\n꿈이 아니었습니다.\n하루가 지나간다.")
        if sleep_check==0:
            sleep_check+=1
        else:
            sleep_stack+=1
            if sleep_stack==3:
                print(over[2])
                game_end==0
                break
        break
    elif day == "전투":
        fight+=1
        sleep_check==0
        print("[전투] 아무나 맞을사람 튀어와!!! 당신은 포효합니다...")
        print("근처 외계 헬스구역에서 3대 900을 치던 외계인이 당신의 패기에 감동해 나타납니다.")
        print("외계인: 난 너의 열정에 감동했다... 함께 우정을 겨뤄보자!!")
        print("[체력 -70]\n너무 아픈 우정은 우정이 아니었음을...\n하루가 지나간다.")
    
    else:
        print("제대로 입력해주세요.")

    break


while game_end==1:
    print(" --- 다섯번째 날 (금) ---")
    if player[1]<=0:
        print(over[2])
        game_end==0
        break
    print(" ! 근처에 단단히 잠긴 철문이 보입니다. 열쇠가 있다면 열 수 있을 것 같은데...")
    print(f"[ 이름: {player[0]} 체력: {player[1]} 인벤: {player[2]} ]")
    day = input("[ 탐색 / 수면 / 전투 ]")
    if day == "탐색":
        search+=1
        sleep_check==0
        print("[탐색] 당신은 눈 앞의 철문으로 다가갔다.")
        if "열쇠" in inv:
            print("마침 어제 찾은 열쇠가 있다! 구멍에 찰칵 소리를 내며 돌아간다.")
            print("당신을 맞이하는 것은...\n검은 제복을 입은 근엄한 외계인이었다...\n당신의 인기척에도 불구하고 외계인은 한 치의 움직임도 없이 가만히 서있는다.")
            
            answer=input("외계인에게 먼저 한마디 할 기회다... 외계인에게 하고싶은 말을 해보자...")
            if "외계총" in inv:
                print(f"{answer}!!!! 당신은 소리지르며 외계인에게 돌격한다.")
                print("당신은 능숙하게 낙지탄을 외계총에 끼워넣고 최대출력으로 외계인의 뒤통수에 가격한다.")
                print("분명 방아쇠는 한 번만 당겼는데 56방이나 나가는 것, 이것이 외계의 기술인가...")
                print(root[1])
                game_end==0
                break
            else:
                print(f"{answer}!!!! 당신은 소리지르며 외계인에게 돌격한다.")
                print("그러나... 외계인을 물리칠 무기가 당신의 손에는 없는 것 같군요.")
                print("당신은 연약한 팔을 휘둘러 외계인을 공격해봅니다.")
                print(over[1])
                game_end==0
                break
        else:
            print("그러나 열쇠가 없어서 들어갈 수가 없다...\n두드려봐도 텅 빈 메아리만 울릴 뿐이었다.\n하루가 지나간다.")
        break
    elif day == "수면":
        sleep+=1
        print("[수면] 이건 전부 다 꿈일거야... 당신은 현실을 부정하며 눈을 감습니다.\n꿈이 아니었습니다.\n하루가 지나간다.")
        if sleep_check==0:
            sleep_check+=1
        else:
            sleep_stack+=1
            if sleep_stack==3:
                print(over[2])
                game_end==0
                break
        break
    elif day == "전투":
        fight+=1
        sleep_check==0
        print("[전투] 아무나 맞을사람 튀어와!!! 당신은 포효합니다...")
        print("그러나 아무도 대답해주지 않습니다. 머쓱하군요.")
    
    else:
        print("제대로 입력해주세요.")

    break


while game_end==1:
    print(" --- 여섯번째 날 (토) ---")
    if player[1]<=0:
        print(over[2])
        game_end==0
        break
    print(" ! 외계인 거주구역에 들어온 것 같습니다. 조심하는게 좋겠습니다.")
    print(f"[ 이름: {player[0]} 체력: {player[1]} 인벤: {player[2]} ]")
    day = input("[ 탐색 / 수면 / 전투 ]")

    if day == "탐색":
        search+=1
        print("당신은 너무 배가고파 외계거주구역 앞의 쓰레기통을 뒤집니다.\n그 안에는 신묘한 물약이 있습니다...")
        answer=input("마실까요? (네/아니오)")
        if answer=="네":
            print(root[0])
            game_end==0
            break
        else:
            print(over[2])
            game_end==0
    
        break
    elif day == "수면":
        sleep+=1
        print("[수면] 이건 전부 다 꿈일거야... 당신은 현실을 부정하며 눈을 감습니다.\n차가운 바닥에 몸을 뉘이려는 순간 누가 일으켜 세웁니다.")
        print("외계인 비밀요원입니다. 그리고 무언가를 당신에게 제안하는데, 실험체가 되라는 내용이 아닙니다. 본인들과 같은 종족이 되지 않겠냐는 제안입니다!")
        answer=input("당신의 선택은? (네/아니오)")
        if answer=="네":
            print(root[0])
            game_end==0
            break
        else:
            print(over[0])
            game_end==0
        break
    elif day == "전투":
        fight+=1
        sleep_check==0
        print("[전투] 아무나 맞을사람 튀어와!!! 당신은 포효합니다...")
        print("외계경찰: 이봐! 여긴 외계경찰이다! 거기 난동꾼 가만히 있어!!")
        answer=input("외계법에 복종할까요? (네/아니오)")
        if answer=="네":
            print(root[2])
            game_end==0
        else:
            player[1]-=50
            print("당신은 외계경찰에게서 도망치는데 성공했다...\n다만 너무 힘들어서 체력이 나갔다.\n[체력 -50]\n하루가 지나간다.")
    
    else:
        print("제대로 입력해주세요.")

    break


while game_end==1:
    print(" --- 마지막 날 (일) ---")
    if player[1]<=0:
        print(over[2])
        game_end==0
        break
    print(" ! 돌아본 곳은 이제 다 돌아본 것 같습니다...")
    print(f"[ 이름: {player[0]} 체력: {player[1]} 인벤: {player[2]} ]")
    day = input("[ 탐색 / 수면 / 전투 ]")

    if day == "탐색":
        search+=1
        print("뭐가 있나 두리번거려보니 근처 벤치에 놓인 신묘한 물약을 발견합니다. 왜인지 마시면 모든 고통이 끝날 것만 같은 느낌이 듭니다.")
        answer=input("마실까요? (네/아니오)")
        if answer=="네":
            print(root[0])
            game_end==0
            break
        else:
            print(over[2])
            game_end==0
        break
    elif day == "수면":
        sleep+=1
        print("[수면] 이건 전부 다 꿈일거야... 당신은 현실을 부정하며 눈을 감습니다.\n차가운 바닥에 몸을 뉘이려는 순간 누가 일으켜 세웁니다.")
        print("외계인 비밀요원입니다. 그리고 무언가를 당신에게 제안하는데, 실험체가 되라는 내용이 아닙니다. 본인들과 같은 종족이 되지 않겠냐는 제안입니다!")
        answer=input("당신의 선택은? (네/아니오)")
        if answer=="네":
            print(root[0])
            game_end==0
            break
        else:
            print(over[0])
            game_end==0
        break
    elif day == "전투":
        fight+=1
        sleep_check==0
        print("[전투] 아무나 맞을사람 튀어와!!! 당신은 포효합니다...")
        print("외계경찰: 이봐! 여긴 외계경찰이다! 거기 난동꾼 가만히 있어!!")
        answer=input("외계법에 복종할까요? (네/아니오)")
        if answer=="네":
            print(root[2])
            game_end==0
        else:
            player[1]-=50
            print("당신은 외계경찰에게서 도망치는데 성공했다...그러나 힘이 너무 빠져 눈이 감긴다...")
            print(over[2])
            game_end==0
    
    else:
        print("제대로 입력해주세요.")

    break

print("--- 최종 스탯 ---")
print(f"""이름: {player[0]}
체력: {player[1]}
탐색한 횟수: {search}
수면한 횟수: {sleep}
전투한 횟수: {fight}
최종 인벤토리: {inv}
""")

if hidden==1:
    print("히든업적 달성!: 외발이 탐험가")

print("이렇게 당신의 외계여정인 여기서 끝이 납니다...\n다음에는 외계함선에 납치당하지 않도록 노력해봅시다.")
# Out:
# 당신은 외계 함선에 납치당했다! 그대에게 주어진 시간은 단 일주일...
# 아이템과 정보를 모으고 살아남아 탈출해보자.
# 당신의 이름은 미미...
#  --- 첫번째 날 (월) ---
#  ! 당신은 낯선 외계함선에 갇혀있다.
# [ 이름: 미미 체력: 100 인벤: ['없음'] ]
# [수면] 이건 전부 다 꿈일거야... 당신은 현실을 부정하며 눈을 감습니다.
# 꿈이 아니었습니다.
# 하루가 지나간다.
#  --- 두번째 날 (화) ---
#  ! 외계인들의 대화를 엿듣다보니 그들은 '우꿀꿀루' 종족 이라는 것을 알게되었다.
# [ 이름: 미미 체력: 100 인벤: ['없음']
# [수면] 이건 전부 다 꿈일거야... 당신은 현실을 부정하며 눈을 감습니다.
# 꿈이 아니었습니다.
# 하루가 지나간다.
#  --- 세번째 날 (수) ---
#  ! 외계인들에게도 오락채널이 있다는 사실을 알아냈습니다. 이름은 외계도전이라네요...
# [ 이름: 미미 체력: 100 인벤: ['없음'] ]
# [수면] 이건 전부 다 꿈일거야... 당신은 현실을 부정하며 눈을 감습니다.
# 꿈이 아니었습니다.
# 하루가 지나간다.
#  --- 네번째 날 (목) ---
#  ! 역시 우주에 있어서 그런가 창밖 뷰는 끝내주네요.
# [ 이름: 미미 체력: 100 인벤: ['없음'] ]
# [수면] 이건 전부 다 꿈일거야... 당신은 현실을 부정하며 눈을 감습니다.
# 꿈이 아니었습니다.
# 하루가 지나간다.
# 아아... 더이상 버틸 수가 없어...
# 풀썩
# 차가운 외계함선의 바닥에 당신은 힘없이 쓰러집니다. 더이상 앞으로 나아가긴 어려워 보이네요...
# 쪼그라든 당신의 시체는 담당자가 수거해 다른 실험체들의 사료를 만드는데 사용했습니다.
# ***게임오버***
#  --- 다섯번째 날 (금) ---
#  ! 근처에 단단히 잠긴 철문이 보입니다. 열쇠가 있다면 열 수 있을 것 같은데...
# [ 이름: 미미 체력: 100 인벤: ['없음'] ]
# ...
