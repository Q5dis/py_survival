# %% [markdown]
# # 파이썬 일주일 생존게임

# %%
inv=[]
root=[1,2,3]
over=[1,2,3]
player=["temp",100,inv]

root[0]=f"{player[0]}님은 이제 우꿀꿀루 종족의 일원이 되었습니다. 그 물약을 마시자마자 인간의 모습은 온데간데 사라지고 사랑스러운 촉수들이 돋아났네요.\n앞으로 새로운 동료들과 함께 얼마나 많은 지구인을 납치하게 될지 기대됩니다!"
root[1]=f"차가운 강철 바닥에는 옛 두목의 살점이 다진 햄버거 패티처럼 퍼져있네요. 이미 죽은게 확실하지만 산낙지처럼 꿈틀대는 근육이 기분 나쁩니다. \n이제는 텅 빈 방 안을 메우는 짭짤하고 비릿한 이 냄새, 승리의 냄새가 분명하군요! 우꿀꿀루 종족의 새로운 두목 {player[0]}님을 찬양하라!"
root[2]=f"{player[0]}님은 우꿀룰루 종족의 실험체가 되는 서류에 서명했습니다. 이제 지구에 있는 엄마아빠 친구들을 다시 만날 수는 없지만 들어보세요... \n목성뷰 원룸에 기초적인 의식주가 평생 무료제공됩니다. 이 경제에 말이죠! 다만 어느날 눈을 감았다 뜨면 모르는 팔이 하나 더 생겨있을지도 모릅니다..."

over[0]=f"{player[0]}님은 우꿀꿀루 종족의 제안을 거절했습니다. 그들은 잠시 서로 머리를 맞대어 고민하는 듯 싶더니... 당신에게 외계총을 발사합니다! 그것도 56방이나요!\n한 발만 맞아도 죽었을텐데 56방은 역시 너무했습니다. {player[0]}님은 구멍이 숭숭 난 채로 바닥에서 식어갑니다.\n마지막 의식이 바라보는 건 내 덩치와 맞먹는 상자를 들고 다가오는 우꿀꿀루족 청소부입니다. 치우는데 고생 좀 하겠네요. \n***게임 오버***"
over[1]=f"{player[0]}님은 두 눈을 꾹 감고 방아쇠를 당겨봅니다. 그런데 총알이 장전되지 않았던 것일까요? 텅 빈 딱딱 소리만 나고 발사되지 않습니다. \n당신은 멋쩍게 웃어보지만 우꿀꿀루 두목은 그런 미인계에 넘어가지 않습니다. 즉시 사방에서 광선이 날아와 당신을 회색 재로 만들어버리네요.\n그래도 고통은 없었으니 호상입니다!\n***게임오버***"
over[2]=f"아아... 더이상 버틸 수가 없어...\n풀썩\n차가운 외계함선의 바닥에 당신은 힘없이 쓰러집니다. 더이상 앞으로 나아가긴 어려워 보이네요...\n쪼그라든 당신의 시체는 담당자가 수거해 다른 실험체들의 사료를 만드는데 사용했습니다.\n***게임오버***"


print("당신은 외계 함선에 납치당했다! 그대에게 주어진 시간은 단 일주일...\n아이템과 정보를 모으고 살아남아 탈출해보자.")

player[0] = input("납치당한 그대의 이름은...: ")
print(f"당신의 이름은 {player[0]}...")

while True:
    print(f"!!!이름: {player[0]}\n!!!체력: {player[1]}\n!!!인벤: {player[2]}")
    mon = input("첫번째 날: 눈 앞에 놓인 물 한대접... 마실까 말까 네/아니오")
    if mon == "인벤":
        if inv:
            print("인벤토리 항목:", inv)
        else:
            print("인벤토리에 항목이 없습니다.")
    elif mon == "네":
        print("true")
        break
    elif mon == "아니오":
        print("false")
        break
    else:
        print("제대로 입력해주세요.")
# Out:
# 당신은 외계 함선에 납치당했다! 그대에게 주어진 시간은 단 일주일...
# 아이템과 정보를 모으고 살아남아 탈출해보자.
# 당신의 이름은 gugu...
# !!!이름: gugu
# !!!체력: 100
# !!!인벤: []
# 제대로 입력해주세요.
# !!!이름: gugu
# !!!체력: 100
# !!!인벤: []
# true
